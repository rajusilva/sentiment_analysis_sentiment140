# %% [markdown]
# # Sentiment 140 Datasets

# %% [markdown]
# #### Get dataset from HuggingFace website

# %%
test_url='https://huggingface.co/datasets/stanfordnlp/sentiment140/resolve/refs%2Fconvert%2Fparquet/sentiment140/test/0000.parquet'
# !wget {test_url}

train_url='https://huggingface.co/datasets/stanfordnlp/sentiment140/resolve/refs%2Fconvert%2Fparquet/sentiment140/train/0000.parquet'
# !wget {train_url}
# Out:
# --2026-02-05 11:00:19--  https://huggingface.co/datasets/stanfordnlp/sentiment140/resolve/refs%2Fconvert%2Fparquet/sentiment140/test/0000.parquet
# Resolving huggingface.co (huggingface.co)... 13.225.5.95, 13.225.5.26, 13.225.5.100, ...
# Connecting to huggingface.co (huggingface.co)|13.225.5.95|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: /api/resolve-cache/datasets/stanfordnlp/sentiment140/807548e523c44caceeb4cb7f950caf7fb5008711/sentiment140%2Ftest%2F0000.parquet?%2Fdatasets%2Fstanfordnlp%2Fsentiment140%2Fresolve%2Frefs%2Fconvert%2Fparquet%2Fsentiment140%2Ftest%2F0000.parquet=&etag=%22257dd19c1e10394c0bcf096accc5bcef293f6dee%22 [following]
# ...

# %%
import pandas as pd
df_raw = pd.read_parquet('0000.parquet.1')
df_raw.info()
df_raw
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1600000 entries, 0 to 1599999
# Data columns (total 5 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   text       1600000 non-null  object
#  1   date       1600000 non-null  object
#  2   user       1600000 non-null  object
#  3   sentiment  1600000 non-null  int32
#  4   query      1600000 non-null  object
# dtypes: int32(1), object(4)
# memory usage: 54.9+ MB
#                                                       text  \
# 0        @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1        is upset that he can't update his Facebook by ...
# 2        @Kenichan I dived many times for the ball. Man...
# 3          my whole body feels itchy and like its on fire
# 4        @nationwideclass no, it's not behaving at all....
# ...                                                    ...
# 1599995  Just woke up. Having no school is the best fee...
# ...

# %%
df_raw['query'].value_counts()
# Out:
# query
# NO_QUERY    1600000
# Name: count, dtype: int64

# %%
df_raw.loc[1599997]['text']
# Out:
# 'Are you ready for your MoJo Makeover? Ask me for details '

# %% [markdown]
# #### Get dataset from StanfordNLP website

# %%
url='https://cs.stanford.edu/people/alecmgo/trainingandtestdata.zip'
# !wget {url}
# !unzip trainingandtestdata.zip
# Out:
# --2026-01-28 08:03:19--  https://cs.stanford.edu/people/alecmgo/trainingandtestdata.zip
# Resolving cs.stanford.edu (cs.stanford.edu)... 171.64.64.64
# Connecting to cs.stanford.edu (cs.stanford.edu)|171.64.64.64|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 81363704 (78M) [application/zip]
# Saving to: 'trainingandtestdata.zip'
#
# trainingandtestdata 100%[===================>]  77.59M   265KB/s    in 5m 35s
#
# 2026-01-28 08:08:55 (237 KB/s) - 'trainingandtestdata.zip' saved [81363704/81363704]
#
# Archive:  trainingandtestdata.zip
#   inflating: testdata.manual.2009.06.14.csv
#   inflating: training.1600000.processed.noemoticon.csv

# %%
cols = ['sentiment','id','date','query_string','user','text']
df_processed = pd.read_csv('training.1600000.processed.noemoticon.csv',
                        header=None, names=cols,encoding="latin-1")
df_processed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1600000 entries, 0 to 1599999
# Data columns (total 6 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   sentiment     1600000 non-null  int64
#  1   id            1600000 non-null  int64
#  2   date          1600000 non-null  object
#  3   query_string  1600000 non-null  object
#  4   user          1600000 non-null  object
#  5   text          1600000 non-null  object
# dtypes: int64(2), object(4)
# memory usage: 73.2+ MB
